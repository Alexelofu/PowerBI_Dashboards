# %%
import pandas as pd
import numpy as np
import time
import os
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
df1 = pd.read_csv('amsterdam_weekdays.csv')
df2 = pd.read_csv('amsterdam_weekends.csv')
df3 = pd.read_csv('athens_weekdays.csv')
df4 = pd.read_csv('athens_weekends.csv')
df5 = pd.read_csv('barcelona_weekdays.csv')
df6 = pd.read_csv('barcelona_weekends.csv')
df7 = pd.read_csv('berlin_weekdays.csv')
df8 = pd.read_csv('berlin_weekends.csv')
df9 = pd.read_csv('budapest_weekdays.csv')
df10 = pd.read_csv('budapest_weekends.csv')
df11 = pd.read_csv('lisbon_weekdays.csv')
df12 = pd.read_csv('lisbon_weekends.csv')
df13 = pd.read_csv('london_weekdays.csv')
df14 = pd.read_csv('london_weekends.csv')
df15 = pd.read_csv('paris_weekdays.csv')
df16 = pd.read_csv('paris_weekends.csv')
df17 = pd.read_csv('rome_weekdays.csv')
df18 = pd.read_csv('rome_weekends.csv')
df19 = pd.read_csv('vienna_weekdays.csv')
df20 = pd.read_csv('vienna_weekends.csv')

# %%
df3.head()
# Out:
#      city      dow     realSum        room_type  room_shared  room_private  \
# 0  Athens  Weekday  129.824479  Entire home/apt        False         False
# 1  Athens  Weekday  138.963748  Entire home/apt        False         False
# 2  Athens  Weekday  156.304924  Entire home/apt        False         False
# 3  Athens  Weekday   91.627024  Entire home/apt        False         False
# 4  Athens  Weekday   74.051508     Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  ...  \
# 0                4              False      0    0  ...
# 1                4               True      1    0  ...
# 2                3               True      0    1  ...
# 3                4               True      1    0  ...
# 4                2              False      0    0  ...
#
#    guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# 0                         100         2  2.813964    0.881890   55.348572
# ...

# %%
dfs = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20])

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51707 entries, 0 to 1798
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city                        51707 non-null  object
#  1   dow                         51707 non-null  object
#  2   realSum                     51707 non-null  float64
#  3   room_type                   51707 non-null  object
#  4   room_shared                 51707 non-null  bool
#  5   room_private                51707 non-null  bool
#  6   person_capacity             51707 non-null  int64
#  7   host_is_superhost           51707 non-null  bool
#  8   multi                       51707 non-null  int64
#  9   biz                         51707 non-null  int64
#  10  cleanliness_rating          51707 non-null  int64
#  11  guest_satisfaction_overall  51707 non-null  int64
#  12  bedrooms                    51707 non-null  int64
# ...

# %%
dfs.to_csv("bnb.csv", index=False)
